# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/adefemi/Downloads/MIT-STEP3.xlsx')
df.rename(columns={'Unnamed: 1':'links'},inplace=True) #Renaming column

# %%
print('='*50)
print('CHECKING FOR NULL VALUES FOR EACH COLUMN')
print('='*50)

col = df.columns
for i in col:
    null = df[i].isnull().sum()
    print(f'{i:<8} > {null:>2}')
# Out:
# ...
# CHECKING FOR NULL VALUES FOR EACH COLUMN
# ...
# groupId  >  0
# links    >  0

# %%
# Out:
# <bound method NDFrame.astype of 0        https://www.parts-catalogs.com/eu/demo#/parts?...
# 1        https://www.parts-catalogs.com/eu/demo#/parts?...
# 2        https://www.parts-catalogs.com/eu/demo#/parts?...
# 3        https://www.parts-catalogs.com/eu/demo#/parts?...
# 4        https://www.parts-catalogs.com/eu/demo#/parts?...
#                                ...
# 90481    https://www.parts-catalogs.com/eu/demo#/parts?...
# 90482    https://www.parts-catalogs.com/eu/demo#/parts?...
# 90483    https://www.parts-catalogs.com/eu/demo#/parts?...
# 90484    https://www.parts-catalogs.com/eu/demo#/parts?...
# 90485    https://www.parts-catalogs.com/eu/demo#/parts?...
# Name: links, Length: 90486, dtype: object>
